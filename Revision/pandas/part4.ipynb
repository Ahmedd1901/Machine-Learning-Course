# %%
import pandas as pd
df = pd.read_csv('data.csv')

# %%
df.groupby('department')['salary'].mean()
# Out:
# department
# FINANCE    5170.00
# HR         6421.25
# IT         9350.00
# Name: salary, dtype: float64

# %%
df.groupby(
    ["department", "age"]
)["salary"].mean()
# Out:
# department  age
# FINANCE     32     5170.0
# HR          22     5500.0
#             30     7342.5
# IT          24     8800.0
#             26     9900.0
# Name: salary, dtype: float64

# %%
df.groupby("department")["salary"].agg(
    ["mean", "min", "max"]
)
# Out:
#                mean     min     max
# department
# FINANCE     5170.00  5170.0  5170.0
# HR          6421.25  5500.0  7342.5
# IT          9350.00  8800.0  9900.0

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)
