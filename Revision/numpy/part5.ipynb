# %%
import numpy as np

# %%
data = np.array([10,20,30,40,50])
np.sum(data)
# Out:
# np.int64(150)

# %%
np.mean(data)
# Out:
# np.float64(30.0)

# %%
np.median(data)
# Out:
# np.float64(30.0)

# %%
np.var(data)
# Out:
# np.float64(200.0)

# %%
np.std(data)
# Out:
# np.float64(14.142135623730951)

# %%
## mean of each column
data = np.array([
    [10, 20, 30],
    [20, 40, 60],
    [30, 60, 90]
])
np.mean(data,axis=0)
# Out:
# array([20., 40., 60.])

# %%
## mean of each row
np.mean(data,axis=1)
# Out:
# array([20., 40., 60.])

# %%
np.argmax(data)
# Out:
# np.int64(8)

# %%
flattened = data.flatten()
np.sort(flattened)
# Out:
# array([10, 20, 20, 30, 30, 40, 60, 60, 90])

# %%
np.sort(flattened)[::-1]
# Out:
# array([90, 60, 60, 40, 30, 30, 20, 20, 10])

# %%
scores = np.array([40, 60, 80, 30])

result = np.where(scores >= 50, "Pass", "Fail")

print(result)
# Out:
# ['Fail' 'Pass' 'Pass' 'Fail']

# %%
np.random.randint(1, 10)
# Out:
# 4

# %%
np.random.rand(5)
# Out:
# array([0.81255919, 0.10588909, 0.81010218, 0.88715142, 0.34675218])

# %%
np.random.randint(1, 10, size=5)
# Out:
# array([8, 6, 3, 8, 9], dtype=int32)

# %%
np.random.randint(
    1,
    100,
    size=(3, 4)
)
# Out:
# array([[93, 95, 34, 18],
#        [68, 99, 24,  3],
#        [98,  5, 59, 97]], dtype=int32)

# %%
data = np.array([10, 20, np.nan, 40])
np.isnan(data)
# Out:
# array([False, False,  True, False])

# %%
np.nanmean(data)
# Out:
# np.float64(23.333333333333332)

# %%
data = np.array([1, 2, np.inf, 4])

print(np.isinf(data))
# Out:
# [False False  True False]
