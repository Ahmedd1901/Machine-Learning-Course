# %%
sett = {1,2,3,4}
removed = sett.pop()

# %%
print(removed)
# Out:
# 1

# %%
print(sett)
# Out:
# {2, 3, 4}

# %%
3 in sett
# Out:
# True

# %%
set1 = {1,2,3}
set2 = {3,4,5,6}
print(set1 | set2)
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}

# %%
print(set1.intersection(set2))
print(set1 & set2)
# Out:
# {3}
# {3}

# %%
print(set1.difference(set2))
print(set1 - set2)
# Out:
# {1, 2}
# {1, 2}

# %%
print(set1.symmetric_difference(set2))
print(set1 ^ set2)
# Out:
# {1, 2, 4, 5, 6}
# {1, 2, 4, 5, 6}

# %%
text = "ear hard high apple mouth ear and or apple"
words = text.split()
print(words)
# Out:
# ['ear', 'hard', 'high', 'apple', 'mouth', 'ear', 'and', 'or', 'apple']

# %%
unique_words = set(words)
print(unique_words)
# Out:
# {'mouth', 'high', 'ear', 'and', 'hard', 'or', 'apple'}

# %%
settt = {1,2,3,4}
settt.remove(4)
settt.discard(5)
print(settt)
# Out:
# {1, 2, 3}
