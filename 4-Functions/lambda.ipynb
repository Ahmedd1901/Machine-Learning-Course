# %% [markdown]
# ## lambda functions

# %%
# def addition(a,b):
#     return a + b

# addition(5,6)

# %%
addition = lambda a,b : a + b
print(addition(5,6))
# Out:
# 11

# %%
# def even(num): 
#     if num % 2 == 0:
#         return True
# print(even(24))

# %%
even1 = lambda num : num % 2 == 0
print(even1(5))
# Out:
# False

# %%
addition1 = lambda x,y,z : x+y+z
print(addition1(2,3,4))
# Out:
# 9

# %%
# ## map()
numbers = [1,2,3,4,5,6]
# def square(number):
#     return number**2

# square(2)

# %%
listt = list(map(lambda x:x**2,numbers))
print(listt)
# Out:
# [1, 4, 9, 16, 25, 36]
