# %%
## function that converts temperature

def convert_temp(temp,unit):
    """this function converts temperature from celsius to 
    fahrenheit and vice versa"""
    if unit == 'c':
        return temp * 9/5 + 32
    elif unit == 'f':
        return (temp - 32) * 5/9
    else:
        return None
    
print(convert_temp(25,'c'))
print(convert_temp(77,'f'))
# Out:
# 77.0
# 25.0

# %%
char = str()
def strong_pass_checker(password):
    if len(password) < 8 :
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char in "!@#$%^&*()_+" for char in password):
        return False
    return True

print(strong_pass_checker("weakpassword"))
print(strong_pass_checker("aA7@f6574gh"))
# Out:
# False
# True

# %%
def calc_total_cost(cart):
    total_cost = 0
    for item in cart:
        total_cost+=item['price']* item['quantity']
    
    return total_cost

cart = [{'name': 'apple','price': 1 , 'quantity': 4},
        {'name': 'orange','price': 2 , 'quantity': 6},
        {'name': 'banana','price': 0.75 , 'quantity': 3}
        ]

print(calc_total_cost(cart))
# Out:
# 18.25

# %%
def is_palindrome(string):
    string = string.lower().replace(" ","")
    return string == string[::-1]

string1 = "a man a plan a canal Panama"
string2 = "ahmed"
print(is_palindrome(string1))
print(is_palindrome(string2))
# Out:
# True
# False

# %%
## calculate the factorial of a number using recursion

def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
print(factorial(5))
# Out:
# 120
