# %%
from concurrent.futures import ThreadPoolExecutor
import time

def print_numbers(i):
    time.sleep(1)
    return f"Number: {i}"

numbers = [1,2,3,4,5,6]

with ThreadPoolExecutor(max_workers=3) as executor:
    results = executor.map(print_numbers,numbers)

for result in results:
    print(result)
# Out:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5
# Number: 6

# %%
from concurrent.futures import as_completed

with ThreadPoolExecutor(max_workers=3) as executor:
    futures = [executor.submit(print_numbers, n) for n in numbers]

    for future in as_completed(futures):
        print(future.result())
# Out:
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5
# Number: 6
