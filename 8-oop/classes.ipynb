# %% [markdown]
# ### Classes and objects

# %%
class car:
    pass
audi = car()
bmw = car()
print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)

# %%
class Dog:
    ## constructor
    def __init__(self,name,age):
        self.name = name
        self.age = age

## creating object
dog1 = Dog("buddy",5)
print(dog1.name)
print(dog1.age)
# Out:
# buddy
# 5

# %%
class Cat:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def meow(self):
        print(f"{self.name} says meow")
    
cat1 = Cat('lola',2)
cat1.meow()
# Out:
# lola says meow

# %%
class BankAccount:
    def __init__(self,owner,balance):
        self.owner = owner
        self.balance = balance
    def deposit(self,amount):
        self.balance += amount
        print(f"successful deposit. The current balance is {self.balance}")
    
    def withdraw(self,amount):
        if amount > self.balance:
            print("insufficient funds")
        else:
            self.balance -= amount
            print(f"current balance is {self.balance}")
    def get_balance(self):
        return self.balance
    
bankAccount1 = BankAccount('ahmed',25000)
print(bankAccount1.get_balance())
bankAccount1.deposit(3000)
bankAccount1.withdraw(23000)
bankAccount1.withdraw(6000)
# Out:
# 25000
# successful deposit. The current balance is 28000
# current balance is 5000
# insufficient funds
