# %% [markdown]
# ## importing modules and packages

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt,pi
print(sqrt(36))
print(pi)
# Out:
# 6.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from packages.math import add
add(2,4)
# Out:
# 6

# %%
import array
arr = array.array('b',[1,2,3])
print(arr)
# Out:
# array('b', [1, 2, 3])

# %%
import random
print(random.randint(1,10))
print(random.choice(['ahmed','mohamed','mahmoud']))
# Out:
# 2
# mohamed

# %%
import os
print(os.getcwd())
# Out:
# /home/ahmed/Desktop/LearnAi/5-modules_packages

# %%
os.mkdir('test_dir')

# %%
## high level operations on files

import shutil
shutil.copyfile('source.txt','distination.txt')
# Out:
# 'distination.txt'

# %%
## Data Serialization
import json
data = {'name': 'ahmed', 'age': 24}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))
parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "ahmed", "age": 24}
# <class 'str'>
# {'name': 'ahmed', 'age': 24}
# <class 'dict'>

# %%
## csv
import csv
with open('example.csv',mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['ahmed', 24])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['ahmed', '24']

# %%
## datetime
from datetime import datetime,timedelta
now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-01-04 19:05:09.703587
# 2026-01-03 19:05:09.703587

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1767546369.9045758
# 1767546371.9050756

# %%
## regular expression
import re
pattern = r'\d+'
text = 'There are 123 apples'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
